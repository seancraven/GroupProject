# %%
import os
print(os.getcwd())
# Out:
# /Users/tikantsoi/Documents/GitHub/GroupProject

# %%
from src.pet_3.data import Pets

# %%
train = Pets("./src/pet_3", split = "all_train", binary_labels = True)

# %%
a, b = train.validation_split(0.2)

# %%
a.images
# Out:
# ['wheaten_terrier_52.jpg',
#  'Abyssinian_221.jpg',
#  'great_pyrenees_171.jpg',
#  'great_pyrenees_181.jpg',
#  'chihuahua_135.jpg',
#  'boxer_106.jpg',
#  'British_Shorthair_91.jpg',
#  'Egyptian_Mau_149.jpg',
#  'english_cocker_spaniel_37.jpg',
#  'Persian_4.jpg',
#  'yorkshire_terrier_126.jpg',
#  'pug_28.jpg',
#  'english_cocker_spaniel_77.jpg',
#  'staffordshire_bull_terrier_121.jpg',
#  'British_Shorthair_79.jpg',
#  'great_pyrenees_164.jpg',
#  'scottish_terrier_75.jpg',
#  'Sphynx_84.jpg',
#  'Persian_175.jpg',
#  'shiba_inu_36.jpg',
#  'shiba_inu_177.jpg',
#  'american_pit_bull_terrier_17.jpg',
#  'miniature_pinscher_138.jpg',
#  'British_Shorthair_129.jpg',
#  'Persian_69.jpg',
#  'wheaten_terrier_149.jpg',
#  'leonberger_153.jpg',
#  'saint_bernard_162.jpg',
#  'Birman_47.jpg',
#  'boxer_102.jpg',
#  'chihuahua_94.jpg',
#  'wheaten_terrier_170.jpg',
#  'american_pit_bull_terrier_89.jpg',
#  'scottish_terrier_160.jpg',
#  'shiba_inu_142.jpg',
#  'keeshond_17.jpg',
# ...

# %%
b.images
# Out:
# ['miniature_pinscher_112.jpg',
#  'japanese_chin_22.jpg',
#  'shiba_inu_128.jpg',
#  'Egyptian_Mau_25.jpg',
#  'Abyssinian_85.jpg',
#  'german_shorthaired_193.jpg',
#  'Bengal_102.jpg',
#  'keeshond_130.jpg',
#  'Siamese_94.jpg',
#  'Persian_135.jpg',
#  'leonberger_179.jpg',
#  'american_bulldog_192.jpg',
#  'Bengal_18.jpg',
#  'basset_hound_4.jpg',
#  'boxer_164.jpg',
#  'Sphynx_133.jpg',
#  'shiba_inu_159.jpg',
#  'British_Shorthair_74.jpg',
#  'British_Shorthair_277.jpg',
#  'pomeranian_81.jpg',
#  'saint_bernard_42.jpg',
#  'Bengal_79.jpg',
#  'Siamese_180.jpg',
#  'shiba_inu_123.jpg',
#  'havanese_125.jpg',
#  'Birman_78.jpg',
#  'american_pit_bull_terrier_54.jpg',
#  'samoyed_72.jpg',
#  'Bombay_117.jpg',
#  'keeshond_54.jpg',
#  'newfoundland_106.jpg',
#  'pomeranian_72.jpg',
#  'american_pit_bull_terrier_161.jpg',
#  'Maine_Coon_158.jpg',
#  'american_bulldog_130.jpg',
#  'shiba_inu_77.jpg',
#  'basset_hound_9.jpg',
#  'beagle_35.jpg',
#  'Siamese_77.jpg',
# ...
